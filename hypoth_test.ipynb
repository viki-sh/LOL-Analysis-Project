# %%
#Null : PGA has no effect on winning, so the win rate of the higher PGA team should be around 50%.
#Alt :  Higher PGA teams should win significantly more than 50% of the time.

#test statistic : # games won by team with higher PGA / total number of games

# %%
import pandas as pd

# %%
df = pd.read_csv("transformed_league_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0            gameid  side      pick1  \
# 0             0             0           0  FRA1TMNT1/450135  Blue     Rumble
# 1             1             1           1  FRA1TMNT1/450135   Red       Gnar
# 2             2             2           2  FRA1TMNT1/450138  Blue  Lissandra
# 3             3             3           3  FRA1TMNT1/450138   Red     Rumble
# 4             4             4           4  FRA1TMNT1/450168  Blue       Gnar
#
#        pick2    pick3     pick4  pick5        ban1      ban2       ban3 ban4  \
# 0  Jarvan IV   Syndra     Sivir  Annie     Alistar      Azir     Irelia  NaN
# 1     Rengar     Ahri    Graves  Janna     Rek'Sai   LeBlanc   Kassadin  NaN
# 2    Rek'Sai   Xerath  Tristana  Janna     LeBlanc  Kassadin    Lee Sin  NaN
# 3     Rengar   Syndra     Sivir  Annie        Gnar      Azir     Irelia  NaN
# 4    Lee Sin  Nidalee     Corki  Janna  Cassiopeia   Rek'Sai  Lissandra  NaN
#
#   ban5  result  num_counters  num_counters_banned  PGA
# 0  NaN       0             0                    1    1
# 1  NaN       1             0                    1    1
# 2  NaN       1             0                    0    0
# 3  NaN       0             2                    1    3
# 4  NaN       1             0                    0    0
